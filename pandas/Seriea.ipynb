# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ### Creating Serieas

# %%
label = ["A","B","C","D"]
py_list = ["Raju","ravi","rajesh","rahul"]
np_array = np.array([1,2,3,4])
dis = {
    "name":"raju",
    "village" :"parasdih",
    "District":"Aurangbad"
}

# %%
pd.Series(py_list)
# Out:
# 0      Raju
# 1      ravi
# 2    rajesh
# 3     rahul
# dtype: object

# %%
pd.Series(np_array,index=label)
# Out:
# A    1
# B    2
# C    3
# D    4
# dtype: int64

# %%
s = pd.Series(py_list)
s
# Out:
# 0      Raju
# 1      ravi
# 2    rajesh
# 3     rahul
# dtype: object

# %%
pd.Series(dis)
# Out:
# name             raju
# village      parasdih
# District    Aurangbad
# dtype: object
