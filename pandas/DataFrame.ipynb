# %%
import numpy as np
import pandas as pd

# %%
data = {
    'name': ["raju", "ravi", "ranjan", "rajesh"],
    'age': [18, 20, 21, 55],
    'Gender': ['M', 'M', 'M', 'M']
}

# %%
framedata = pd.DataFrame(data)

# %%
framedata
# Out:
#      name  age Gender
# 0    raju   18      M
# 1    ravi   20      M
# 2  ranjan   21      M
# 3  rajesh   55      M

# %%
framedata["age"]
# Out:
# 0    18
# 1    20
# 2    21
# 3    55
# Name: age, dtype: int64

# %% [markdown]
# ###  create data frame using list

# %%
listdata = [
    ['raju',29,"cse"],
    ["rahul",21,"cse"],
    ["shivam",25,"agr"]
]
colomns = ["name","age","branch"]

# %%
data= pd.DataFrame(listdata ,columns = colomns)
data
# Out:
#      name  age branch
# 0    raju   29    cse
# 1   rahul   21    cse
# 2  shivam   25    agr

# %% [markdown]
# ### select data

# %%
data['age']
# Out:
# 0    29
# 1    21
# 2    25
# Name: age, dtype: int64

# %%
data[["name","age"]]
# Out:
#      name  age
# 0    raju   29
# 1   rahul   21
# 2  shivam   25

# %% [markdown]
# ### creating new colomns

# %%
data["course"] = ["B.tech","bca","agr"]

# %%
data
# Out:
#      name  age branch  course
# 0    raju   29    cse  B.tech
# 1   rahul   21    cse     bca
# 2  shivam   25    agr     agr

# %% [markdown]
# ### Delete columns

# %%
data.drop("course",axis=1 ,inplace=True )## inplace true changeing perfoming
data.drop([ ])

# %%
data
# Out:
#      name  age branch
# 0    raju   29    cse
# 1   rahul   21    cse
# 2  shivam   25    agr
